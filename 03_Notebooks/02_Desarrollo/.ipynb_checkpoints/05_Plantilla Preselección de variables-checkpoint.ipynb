# %% [markdown]
# # PRESELECCIÓN DE VARIABLES

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import RFE
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from sklearn.inspection import permutation_importance


#Automcompletar rápido
# %config IPCompleter.greedy=True
# Out:
# C:\Users\Jorge\miniconda3\envs\leadscoring\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/Jorge/Documents/PythonDataScience/35_Machine_Learning_Framework/PROYECTOS_ML/01_LEADSCORING'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_df = 'df_tablon.pickle'

# %% [markdown]
# Cargar los datos.

# %%
df = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_df)

# %% [markdown]
# ## MÉTODOS SUPERVISADOS

# %% [markdown]
# ### Preparar x e y

# %%
target = 'contrata_fondos'
x = df.drop(columns = target).copy()
y =  df[target].copy()

# %% [markdown]
# ### Mutual Information

# %% [markdown]
# #### Crear una función para mostrar el resultado

# %%
def ranking_mi(mutual_selector, modo = 'tabla'):
    #Maqueta el ranking
    ranking_mi = pd.DataFrame(mutual_selector, index = x.columns).reset_index()
    ranking_mi.columns = ['variable','importancia_mi']
    ranking_mi = ranking_mi.sort_values(by = 'importancia_mi', ascending = False)
    ranking_mi['ranking_mi'] = np.arange(0,ranking_mi.shape[0])
    #Muestra la salida
    if modo == 'tabla':
        return(ranking_mi)
    else:
        g = ranking_mi.importancia_mi.sort_values().plot.barh(figsize = (12,20))
        g.set_yticklabels(ranking_mi.sort_values(by = 'importancia_mi').variable)
        return(g)

# %% [markdown]
# #### Calcular y revisar

# %%
mutual_selector = mutual_info_classif(x,y)

rank_mi = ranking_mi(mutual_selector, modo = 'grafico')

# %% [markdown]
# #### Seleccionar las variables que pasan

# %% [markdown]
# ##### Definir la posición de la última variable que va a entrar

# %%
posicion_variable_limite = 20

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_mi = ranking_mi(mutual_selector).iloc[0:posicion_variable_limite].variable

# %% [markdown]
# ##### Crear el dataframe con la selección

# %%
x_mi = x[entran_mi].copy()

# %% [markdown]
# ### Recursive Feature Elimination

# %% [markdown]
# #### Instanciar

# %%
rfe = RFE(estimator = XGBClassifier(use_label_encoder=False, n_jobs = -1, eval_metric='auc'))

# %% [markdown]
# #### Entrenar

# %%
rfe.fit(x,y)
# Out:
# RFE(estimator=XGBClassifier(base_score=None, booster=None,
#                             colsample_bylevel=None, colsample_bynode=None,
#                             colsample_bytree=None, enable_categorical=False,
#                             eval_metric='auc', gamma=None, gpu_id=None,
#                             importance_type=None, interaction_constraints=None,
#                             learning_rate=None, max_delta_step=None,
#                             max_depth=None, min_child_weight=None, missing=nan,
#                             monotone_constraints=None, n_estimators=100,
#                             n_jobs=-1, num_parallel_tree=None, predictor=None,
#                             random_state=None, reg_alpha=None, reg_lambda=None,
#                             scale_pos_weight=None, subsample=None,
#                             tree_method=None, use_label_encoder=False,
#                             validate_parameters=None, verbosity=None))

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_rfe = x.columns[rfe.support_]

# %% [markdown]
# #### Crear el dataframe con la selección

# %%
x_rfe = x[entran_rfe].copy()

# %% [markdown]
# ### Permutation Importance

# %% [markdown]
# #### Crear una función para mostrar el resultado

# %%
def ranking_per(predictoras,permutacion):
    ranking_per = pd.DataFrame({'variable': predictoras.columns, 'importancia_per': permutacion.importances_mean}).sort_values(by = 'importancia_per', ascending = False)
    ranking_per['ranking_per'] = np.arange(0,ranking_per.shape[0])
    return(ranking_per)

# %% [markdown]
# #### Instanciar y entrenar

# %%
import warnings
warnings.filterwarnings(action="ignore", message=r'.*Use subset.*of np.ndarray is not recommended')

xgb = XGBClassifier(use_label_encoder=False, n_jobs = -1, eval_metric='auc')

xgb.fit(x,y)

permutacion = permutation_importance(xgb, 
                                     x, y, 
                                     scoring = 'roc_auc',
                                     n_repeats=5, n_jobs = -1)
# Out:
# C:\Users\Jorge\miniconda3\envs\proyecto1\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %% [markdown]
# #### Revisar la salida

# %%
rank_per = ranking_per(x,permutacion)

rank_per.set_index('variable').importancia_per.sort_values().plot.barh(figsize = (12,20));

# %% [markdown]
# #### Seleccionar las variables que pasan

# %% [markdown]
# ##### Definir la posición de la última variable que va a entrar

# %%
posicion_variable_limite = 6

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_per = rank_per.iloc[0:posicion_variable_limite].variable

# %% [markdown]
# ##### Crear el dataframe con la selección

# %%
x_per = x[entran_per].copy()

# %% [markdown]
# ## SELECCIONAR EL MÉTODO FINAL

# %% [markdown]
# Descomentar el método de preselección elegido y dejar comentados el resto.

# %%
x_preseleccionado = x_mi
# x_preseleccionado = x_rfe
# x_preseleccionado = x_per

# %% [markdown]
# ## MÉTODOS NO SUPERVISADOS

# %% [markdown]
# ### Correlación

# %% [markdown]
# #### Crear una función para mostrar el resultado

# %%
def correlaciones_fuertes(df, lim_inf = 0.3, lim_sup = 1,drop_dupli=True):
    #Calcula la matriz de correlación
    c = df.corr().abs()
    #Lo pasa todo a filas
    c= c.unstack()
    #Pasa el índice a columnas y le pone nombres
    c = pd.DataFrame(c).reset_index()
    c.columns = ['var1','var2','corr']
    #A dataframe, filtra limites y ordena en descendiente
    c = c.loc[(c['corr'] > lim_inf) &  (c['corr'] < lim_sup),:].sort_values(by = 'corr', ascending=False)
    #Desduplica las correlaciones (o no si drop_dupli es False)
    c = c if drop_dupli == False else c.drop_duplicates(subset = ['corr'])
    #Devuelve la salida
    return(c)

# %% [markdown]
# #### Calcular y revisar

# %% [markdown]
# ##### Calcular

# %%
cor_finales = correlaciones_fuertes(x_preseleccionado)

# %% [markdown]
# ##### Revisar agregado

# %%
cor_finales.var1.value_counts()
# Out:
# variacion_tasa_empleo_bin_ss            7
# resultado_campana_anterior_oe_ss        7
# euribor3m_qt_rs                         6
# euribor3m_qt_ss                         6
# euribor3m_qt                            5
# euribor3m_yeo_mms                       5
# euribor3m_qt_mms                        4
# euribor3m_yeo_rs                        4
# euribor3m_yeo                           3
# resultado_campana_anterior_oe_mms       3
# resultado_campana_anterior_oe           3
# resultado_campana_anterior_oe_rs        3
# variacion_tasa_empleo_bin_rs            2
# num_dias_ultimo_contacto_disc_ds_ss     2
# num_dias_ultimo_contacto_disc_ds_mms    2
# variacion_tasa_empleo_bin               2
# num_dias_ultimo_contacto_disc_ds_rs     1
# euribor3m_yeo_ss                        1
# variacion_tasa_empleo_bin_mms           1
# Name: var1, dtype: int64

# %% [markdown]
# ##### Revisar detalle

# %%
cor_finales.head(50)
# Out:
#                                      var1  \
# 44                          euribor3m_yeo
# 60                        euribor3m_qt_ss
# 172  num_dias_ultimo_contacto_disc_ds_mms
# 47                          euribor3m_yeo
# 390          variacion_tasa_empleo_bin_ss
# 394          variacion_tasa_empleo_bin_ss
# 5                         euribor3m_qt_rs
# 1                         euribor3m_qt_rs
# 103                          euribor3m_qt
# 144                     euribor3m_yeo_mms
# 24                       euribor3m_qt_mms
# 41                          euribor3m_yeo
# 104                          euribor3m_qt
# 80                       euribor3m_yeo_rs
# 83                       euribor3m_yeo_rs
# 145                     euribor3m_yeo_mms
# 102                          euribor3m_qt
# 62                        euribor3m_qt_ss
# 67                        euribor3m_qt_ss
# 6                         euribor3m_qt_rs
# 27                       euribor3m_qt_mms
# 7                         euribor3m_qt_rs
# 159                     euribor3m_yeo_mms
# 284         variacion_tasa_empleo_bin_mms
# 384          variacion_tasa_empleo_bin_ss
# 90                       euribor3m_yeo_rs
# 134                      euribor3m_yeo_ss
# 206          variacion_tasa_empleo_bin_rs
# 153                     euribor3m_yeo_mms
# 150                     euribor3m_yeo_mms
# 382          variacion_tasa_empleo_bin_ss
# 191     resultado_campana_anterior_oe_mms
# 329   num_dias_ultimo_contacto_disc_ds_rs
# 177  num_dias_ultimo_contacto_disc_ds_mms
# 356      resultado_campana_anterior_oe_ss
# 255   num_dias_ultimo_contacto_disc_ds_ss
# 308         resultado_campana_anterior_oe
# 257   num_dias_ultimo_contacto_disc_ds_ss
# 79                        euribor3m_qt_ss
# 261             variacion_tasa_empleo_bin
# 30                       euribor3m_qt_mms
# 39                       euribor3m_qt_mms
# 380          variacion_tasa_empleo_bin_ss
# 73                        euribor3m_qt_ss
# 70                        euribor3m_qt_ss
# 110                          euribor3m_qt
# 10                        euribor3m_qt_rs
# 119                          euribor3m_qt
# 217          variacion_tasa_empleo_bin_rs
# 354      resultado_campana_anterior_oe_ss
#
#                                      var2      corr
# 44                       euribor3m_yeo_rs  1.000000
# 60                        euribor3m_qt_rs  1.000000
# 172   num_dias_ultimo_contacto_disc_ds_ss  1.000000
# 47                      euribor3m_yeo_mms  1.000000
# 390          variacion_tasa_empleo_bin_rs  1.000000
# 394         variacion_tasa_empleo_bin_mms  1.000000
# 5                            euribor3m_qt  1.000000
# 1                        euribor3m_qt_mms  1.000000
# 103                       euribor3m_qt_ss  1.000000
# 144                      euribor3m_yeo_rs  1.000000
# 24                       euribor3m_yeo_rs  0.865247
# 41                       euribor3m_qt_mms  0.865247
# 104                      euribor3m_yeo_rs  0.865247
# 80                        euribor3m_qt_rs  0.865247
# 83                        euribor3m_qt_ss  0.865247
# 145                          euribor3m_qt  0.865247
# 102                         euribor3m_yeo  0.865247
# 62                          euribor3m_yeo  0.865247
# 67                      euribor3m_yeo_mms  0.865247
# 6                        euribor3m_yeo_ss  0.865247
# 27                      euribor3m_yeo_mms  0.865247
# 7                       euribor3m_yeo_mms  0.865247
# 159          variacion_tasa_empleo_bin_ss  0.750361
# 284                      euribor3m_yeo_rs  0.750361
# 384                      euribor3m_yeo_rs  0.750361
# 90           variacion_tasa_empleo_bin_rs  0.750361
# 134         variacion_tasa_empleo_bin_mms  0.750361
# 206                      euribor3m_yeo_ss  0.750361
# 153             variacion_tasa_empleo_bin  0.750361
# 150          variacion_tasa_empleo_bin_rs  0.750361
# 382                         euribor3m_yeo  0.750361
# 191      num_dias_ultimo_contacto_disc_ds  0.746216
# 329     resultado_campana_anterior_oe_mms  0.746216
# 177      resultado_campana_anterior_oe_ss  0.746216
# 356   num_dias_ultimo_contacto_disc_ds_rs  0.746216
# 255         resultado_campana_anterior_oe  0.746216
# 308  num_dias_ultimo_contacto_disc_ds_mms  0.746216
# 257      resultado_campana_anterior_oe_ss  0.746216
# 79           variacion_tasa_empleo_bin_ss  0.662823
# 261                      euribor3m_qt_mms  0.662823
# 30           variacion_tasa_empleo_bin_rs  0.662823
# 39           variacion_tasa_empleo_bin_ss  0.662823
# 380                       euribor3m_qt_rs  0.662823
# 73              variacion_tasa_empleo_bin  0.662823
# 70           variacion_tasa_empleo_bin_rs  0.662823
# 110          variacion_tasa_empleo_bin_rs  0.662823
# 10           variacion_tasa_empleo_bin_rs  0.662823
# 119          variacion_tasa_empleo_bin_ss  0.662823
# 217      resultado_campana_anterior_oe_ss  0.433668
# 354         variacion_tasa_empleo_bin_mms  0.433668

# %% [markdown]
# #### Filtrar variables

# %% [markdown]
# Meter en una lista las que queramos descartar por alta correlacion y eliminarlas.

# %%
a_eliminar_corr = ['euribor3m_qt', 'euribor3m_yeo_rs']

# %%
x_preseleccionado.drop(columns = a_eliminar_corr, inplace = True)

# %%
x_preseleccionado.columns.to_list()
# Out:
# ['euribor3m_qt_rs',
#  'euribor3m_qt_mms',
#  'euribor3m_yeo',
#  'euribor3m_qt_ss',
#  'euribor3m_yeo_ss',
#  'euribor3m_yeo_mms',
#  'num_dias_ultimo_contacto_disc_ds_mms',
#  'resultado_campana_anterior_oe_mms',
#  'variacion_tasa_empleo_bin_rs',
#  'num_dias_ultimo_contacto_disc_ds',
#  'num_dias_ultimo_contacto_disc_ds_ss',
#  'variacion_tasa_empleo_bin',
#  'variacion_tasa_empleo_bin_mms',
#  'resultado_campana_anterior_oe',
#  'num_dias_ultimo_contacto_disc_ds_rs',
#  'resultado_campana_anterior_oe_ss',
#  'resultado_campana_anterior_oe_rs',
#  'variacion_tasa_empleo_bin_ss']

# %% [markdown]
# ## GUARDAR DATASETS TRAS PRESELECCION DE VARIABLES

# %%
#Definir los nombres de los archivos
nombre_x_preseleccionado = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'x_preseleccionado.pickle'
nombre_y_preseleccionado = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'y_preseleccionado.pickle'

# %%
#Guardar los archivos
x_preseleccionado.to_pickle(nombre_x_preseleccionado)

y_preseleccionado = y.copy()
y_preseleccionado.to_pickle(nombre_y_preseleccionado)

# %%
#Guardar los nombres de las variables finales
nombre_variables_finales = ruta_proyecto + '/05_Resultados/' + 'variables_finales.pickle'

x_preseleccionado.iloc[0].to_pickle(nombre_variables_finales)
