# %% [markdown]
# # EDA

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/Jorge/Documents/PythonDataScience/35_Machine_Learning_Framework/PROYECTOS_ML/01_LEADSCORING'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_cat = 'cat_resultado_calidad.pickle'
nombre_num = 'num_resultado_calidad.pickle'

# %% [markdown]
# Cargar los datos.

# %%
cat = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_cat)
num = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_num)

# %% [markdown]
# ## EDA CATEGÓRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
def frecuencias_cat(df_cat):
    resultado = df_cat.apply(lambda x: x.value_counts(normalize = True)).T.stack()\
                .to_frame().reset_index()\
                .rename(columns={'level_0':'Variable','level_1':'Valor',0: "Frecuencia"})\
                .sort_values(by = ['Variable','Frecuencia'])
    return(resultado)

# %%
frecuencias_cat(cat)
# Out:
#                  Variable                              Valor  Frecuencia
# 25                 ambito              Healthcare Management    0.021776
# 28                 ambito             International Business    0.025155
# 30                 ambito              Media and Advertising    0.027032
# 35                 ambito                 Travel and Tourism    0.027220
# 22                 ambito  Banking, Investment And Insurance    0.043739
# 34                 ambito            Supply Chain Management    0.046368
# 27                 ambito             IT Projects Management    0.049559
# 23                 ambito            Business Administration    0.051436
# 31                 ambito                              OTROS    0.064389
# 32                 ambito              Operations Management    0.064389
# 26                 ambito          Human Resource Management    0.104186
# 29                 ambito               Marketing Management    0.104749
# 24                 ambito                 Finance Management    0.124460
# 33                 ambito                             Select    0.245542
# 47     conociste_facebook                              OTROS    0.000563
# 46     conociste_facebook                                 No    0.999437
# 41       conociste_google                              OTROS    0.002440
# 40       conociste_google                                 No    0.997560
# 43    conociste_periodico                              OTROS    0.000375
# 42    conociste_periodico                                 No    0.999625
# 49  conociste_referencias                              OTROS    0.000939
# 48  conociste_referencias                                 No    0.999061
# 45      conociste_youtube                              OTROS    0.000188
# 44      conociste_youtube                                 No    0.999812
# 51            descarga_lm                                Yes    0.377135
# 50            descarga_lm                                 No    0.622865
# 7                  fuente                              OTROS    0.029472
# 9                  fuente                          Reference    0.043552
# 4                  fuente                               Chat    0.061385
# 8                  fuente                     Organic Search    0.149991
# 5                  fuente                     Direct Traffic    0.337338
# 6                  fuente                             Google    0.378262
# 11        no_enviar_email                                Yes    0.085226
# 10        no_enviar_email                                 No    0.914774
# 13              no_llamar                              OTROS    0.000188
# 12              no_llamar                                 No    0.999812
# 36              ocupacion                              OTROS    0.004505
# 37              ocupacion                            Student    0.024592
# 39              ocupacion               Working Professional    0.087479
# 38              ocupacion                         Unemployed    0.883424
# 3                  origen                              OTROS    0.006758
# 2                  origen                      Lead Add Form    0.048245
# 0                  origen                                API    0.299606
# 1                  origen            Landing Page Submission    0.645391
# 17          ult_actividad                 Email Link Clicked    0.028346
# 16          ult_actividad                      Email Bounced    0.034916
# 14          ult_actividad                  Chat Conversation    0.054627
# 19          ult_actividad                              OTROS    0.055378
# 15          ult_actividad                  Converted to Lead    0.055941
# 20          ult_actividad            Page Visited on Website    0.084100
# 21          ult_actividad                           SMS Sent    0.304862
# 18          ult_actividad                       Email Opened    0.381828

# %% [markdown]
# **Eliminamos los registros detectados como no válidos**

# %%
cat = cat.loc[(cat.no_llamar != 'OTROS') & (cat.no_enviar_email != 'Yes') & (cat.ult_actividad!='Email Bounced')] \
    .drop(columns = ['conociste_facebook',
                     'conociste_google',
                     'conociste_periodico',
                     'conociste_referencias',
                     'conociste_youtube',
                     'no_enviar_email',
                     'no_llamar'])

# %% [markdown]
# **Acualizamos el número de registros en el dataset de numéricos para equipararlo al de categóricos**

# %%
num = num[num.index.isin(cat.index)]

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_categoricos(cat):
    
    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        cat[variable].value_counts().plot.barh(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_categoricos(cat)

# %% [markdown]
# ## EDA NUMÉRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

# %%
estadisticos_cont(num)
# Out:
#                         count        mean  median         std   min    25%  \
# compra                 4865.0    0.419322     0.0    0.493499   0.0    0.0
# visitas_total          4865.0    4.175334     3.0    3.587930   0.0    2.0
# tiempo_en_site_total   4865.0  609.660843   373.0  557.746266   0.0  135.0
# paginas_vistas_visita  4865.0    2.890787     2.5    1.922644   0.0    2.0
# score_actividad        4865.0   14.051593    14.0    0.948082   7.0   14.0
# score_perfil           4865.0   16.299075    16.0    1.424054  11.0   16.0
#
#                          50%     75%     max
# compra                   0.0     1.0     1.0
# visitas_total            3.0     5.0    50.0
# tiempo_en_site_total   373.0  1098.0  2272.0
# paginas_vistas_visita    2.5     4.0    16.0
# score_actividad         14.0    14.0    18.0
# score_perfil            16.0    17.0    20.0

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_continuas(num):
    
    #Calculamos el número de fila que necesitamos
    from math import ceil
    filas = ceil(num.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(num):
        num[variable].plot.density(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_continuas(num)

# %% [markdown]
# ## GUARDAR DATASETS TRAS CALIDAD DE DATOS

# %% [markdown]
# Guarda los avances en cat y num con un sufijo para poder guardar o recuperar avances del proyecto.
#
# En formato pickle para no perder las modificaciones de metadatos.
#
# *NOTA: En algunos casos no hay cambios en los ficheros en esta fase, así que este paso es opcional.Pero si no guardas estos ficheros acuérdate de modificar la importación en el siguiente notebook.*

# %%
#Definir los nombres de los archivos
ruta_cat = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'cat_resultado_eda.pickle'
ruta_num = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'num_resultado_eda.pickle'

# %%
#Guardar los archivos
cat.to_pickle(ruta_cat)
num.to_pickle(ruta_num)
